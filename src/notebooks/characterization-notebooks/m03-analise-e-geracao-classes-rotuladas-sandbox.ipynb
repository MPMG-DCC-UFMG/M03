# %%
import pandas as pd
import re
from collections import Counter
import matplotlib.pyplot as plt
##Classe com vários métodos de pre-processamento de texto em português criado pelo grupo F03
import utils.preprocessing_portuguese as preprossPT

# %%
def limpeza_texto(page_text):
    txt_process = preprossPT.TextPreProcessing()
    
    page_text = page_text.lower()
    
    page_text = txt_process.remove_pronouns(page_text)

    page_text = txt_process.remove_reduced_or_contracted_words(page_text)

    page_text = txt_process.remove_adverbs(page_text)

    page_text = txt_process.remove_special_characters(page_text)

    page_text = txt_process.remove_excessive_spaces(page_text)

    page_text = txt_process.remove_accents(page_text)

    page_text = txt_process.remove_stopwords(page_text)

    page_text = txt_process.remove_symbols_from_numbers(page_text)

    page_text = txt_process.remove_numbers(page_text)

    page_text = txt_process.remove_urls(page_text)
    
    page_text = txt_process.remove_person_names(page_text)
    
    #Removendo letras sozinhas no texto
    page_text = re.sub(r'(?:^| )\w(?:$| )', ' ', page_text).strip()

    page_text = page_text.replace("_","")
    
    return page_text

# %%
def cities_prep(df):
    return df['cities'].str.replace("'","").str.replace(" ",",").str.replace(",,",",").str.replace(",",", ").str.replace("\n","").str.replace("[","").str.replace("]","").str.lower()
def flatten(t):
    return list(set([item.replace(" ","") for sublist in t for item in sublist]))

# %% [markdown]
# ### Gera Classes_v2

# %%
sheet_names = ['sao-bento-abade', 'olaria', 'coqueiral', 'cristais', 'pirapetinga', 'passa-vinte', 'arantina', 'itamarati', 'ribeirao-vermelho', 'ijaci']
file_dir = 'resultado_m03_meta_classes_extraction/resultado_final.xlsx'
all_sheets = []
for sheet in sheet_names:
    df = pd.read_excel(file_dir, sheet_name=sheet)
    df.columns = df.columns.str.lower()
    all_sheets.append(df)
# Concatena todos dataframes em apenas um
df_rotulos = pd.concat(all_sheets)
# Dropa linhas vazias e reseta o indice
#df_rotulos.dropna(how='all', subset=['doc_id', 'title', 'city', 'all_matches', 'meta-class',
#       'real_meta-class', 'real_class', 'key_words', 'obs', 'escaneado'], inplace=True)
df_rotulos.dropna(axis=1, how="all", inplace=True)
df_rotulos.dropna(axis=0, how="all", inplace=True)
df_rotulos.reset_index(drop=True, inplace=True)
df_rotulos.head()
# Out:
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    number                            doc_id  \
# 0     0.0  275acd244d5791013bd8f4b3243a4a1a
# 1     1.0  2309298b1878b216dca666aba446a4cd
# 2     2.0  85c1a53d38e9f0128f437554523bf87c
# 3     3.0  4d6035bf3212568e336fe0ab7d9fb215
# 4     4.0  580e6393365c2957e221de56844dd011
#
#                                                title             city  \
# 0  prefeitura municipal de são bento abade mg adm...  sao-bento-abade
# 1    prefeitura municipal de são bento abade mg  ...  sao-bento-abade
# 2  prefeitura municipal de são bento abade estado...  sao-bento-abade
# 3   prefeitura municipal de são bento abade estad...  sao-bento-abade
# 4  prefeitura municipal de são bento abade estado...  sao-bento-abade
#
#                                          all_matches meta-class  \
# 0                                     ['ata', 'ata']        ATA
# 1                ['ata', 'sessão pública', 'edital']        ATA
# 2  ['ata', 'ata', 'homologação', 'homologação', '...        ATA
# 3                ['ata', 'sessão pública', 'edital']        ATA
# 4      ['ata', 'sessão pública', 'edital', 'edital']        ATA
#
#   real_meta-class                                       real_class  \
# 0             ATA                        ATA DE REGISTRO DE PREÇOS
# 1             ATA                            ATA DE SESSÃO PÚBLICA
# 2             ATA  ATA REFERENTE A FASE DE JULGAMENTO DAS EMPRESAS
# 3             ATA                         ATA DO PREGÃO PRESENCIAL
# 4             ATA                         ATA DO PREGÃO PRESENCIAL
#
#                         key_words  obs  escaneado
# 0  ATA, ATA DE REGISTRO DE PREÇOS  NaN        NaN
# 1            ATA, tomada de preco  NaN        NaN
# 2         ATA, FASE DE JULGAMENTO  NaN        NaN
# 3   ATA, ATA DO PREGÃO PRESENCIAL  NaN        NaN
# 4                 sessao, publica  NaN        NaN

# %%
file_dir = 'resultado_m03_meta_classes_extraction/resultado_final.xlsx'
df_classes = pd.read_excel(file_dir, sheet_name="Classes")
df_classes = df_classes.dropna(subset=['final_class']).reset_index(drop=True)
df_classes.loc[df_classes['final_class']=='impulgnacao', 'final_class'] = 'impugnacao'
df_classes['cities'] = cities_prep(df_classes)
df_classes.loc[df_classes['cities'].isnull(), ['cities', 'num_cities']] = ['pirapetinga', 1]

final_class = df_classes['final_class'].tolist()
df_classes['final_class'] = [limpeza_texto(class_name) for class_name in final_class]

df_classes
# Out:
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#     real_meta-class final_meta-class           processed_classes  count  \
# 0               ATA              ATA         alteracao valor ata      1
# 1               ATA              ATA                         ata     36
# 2               ATA              ATA     ata avaliacao propostas      1
# 3               ATA              ATA            ata cancelamento      1
# 4               ATA              ATA         ata chamada publica      1
# ..              ...              ...                         ...    ...
# 282          OUTROS           OUTROS  termo ratificacao anulacao      1
# 283          OUTROS           OUTROS      termo recisao contrato      1
# 284          OUTROS           OUTROS            termo referencia     18
# 285          OUTROS           OUTROS     termo revogacao certame      3
# 286          OUTROS           OUTROS                    tutorial     25
#
#        final_class validate  \
# 0      outras atas      yes
# 1      outras atas      yes
# 2      outras atas       no
# 3      outras atas       no
# 4      outras atas       no
# ..             ...      ...
# 282    ratificacao       no
# 283  outros termos       no
# 284  outros termos       no
# 285  outros termos       no
# 286       tutorial      yes
#
#                                                    obs  \
# 0    Documento informa a alteração de valor em uma ...
# 1                           formada apenas por tabelas
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 282                                                NaN
# 283                Faz referência ao termo de contrato
# 284                                                NaN
# 285                                                NaN
# 286  Há interesse em considerar esse tipo de docume...
#
#                                      cities  num_cities  \
# 0                                 coqueiral         1.0
# 1                                 coqueiral         1.0
# 2                                 coqueiral         1.0
# 3                                  cristais         1.0
# 4                                  cristais         1.0
# ..                                      ...         ...
# 282                               coqueiral         1.0
# 283                             pirapetinga         1.0
# 284                                cristais         1.0
# 285                               coqueiral         1.0
# 286  arantina, passa-vinte, sao-bento-abade         3.0
#
#                               example
# 0    ff48c8fc20d968e4985064b0d0b66bc0
# 1    671c1fdba8752c0dd41a5203bf50f1ec
# 2    879c6686cee9ce4020449089b84e03d4
# 3    b4a76882d5915a2e110027564a2f9d58
# 4    c8cc587ca217d520a9065b4109a06a5e
# ..                                ...
# 282  eca36e481e8405dddec6d28b5de78d96
# 283  ecdc9df62762be250f174d42959e66a1
# 284  caf058926f02628f74ea45615be041fc
# 285  cf94eb708d3b377bf95bbb0435cd4da3
# 286  4a1b286f67023ebea76f3a99c949926e
#
# [287 rows x 10 columns]

# %%
processed_classes = df_rotulos['real_class'].to_list()
processed_classes = [limpeza_texto(class_name) for class_name in processed_classes]
df_rotulos['processed_classes'] = processed_classes

df_rotulos.loc[df_rotulos['real_meta-class'].isnull(), 'real_meta-class'] = 'NULL'

df_count_class_and_meta = df_rotulos.groupby(['real_meta-class', 'processed_classes', 'meta-class']).size().reset_index(name='count').sort_values(by='count', ascending=False)
df_count_cities = df_rotulos.groupby(['real_meta-class', 'processed_classes']).agg({'city': lambda x: list(set(x))}).reset_index()
df_count_cities['num_cities'] = df_count_cities['city'].apply(lambda x: len(x))

df_count_class_and_meta = pd.merge(left=df_count_class_and_meta, right=df_count_cities, on=['real_meta-class', 'processed_classes'])

df_merge = pd.merge(left=df_count_class_and_meta, right=df_classes[['real_meta-class', 'final_meta-class', 'processed_classes', 'final_class', 'validate', 'obs','example']], 
         on=['real_meta-class', 'processed_classes'], how='left')
df_merge.rename({'city':'cities'}, inplace=True, axis=1)
df_merge = df_merge[['real_meta-class', 'final_meta-class', 'processed_classes', 'count', 'final_class', 'validate', 'obs', 'cities', 'num_cities', 'example', 'meta-class']]
#df_merge.to_csv('resultado_m03_meta_classes_extraction/aba_Classes_v2.csv',index=False)

# %% [markdown]
# # Sheet Classes
# ### Gera Anexo A

# %%
file_dir = 'resultado_m03_meta_classes_extraction/resultado_final.xlsx'
df_classes = pd.read_excel(file_dir, sheet_name="Classes_v2")
df_classes = df_classes.dropna(subset=['final_class']).reset_index(drop=True)
df_classes.loc[df_classes['final_class']=='impulgnacao', 'final_class'] = 'impugnacao'
df_classes['cities'] = cities_prep(df_classes)
df_classes.loc[df_classes['cities'].isnull(), ['cities', 'num_cities']] = ['pirapetinga', 1]

final_class = df_classes['final_class'].tolist()
df_classes['final_class'] = [limpeza_texto(class_name) for class_name in final_class]

df_classes
# Out:
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#     real_meta-class final_meta-class         processed_classes   count  \
# 0            EDITAL           EDITAL          edital licitacao  1207.0
# 1            OUTROS           OUTROS   contrato administrativo   459.0
# 2               ATA              ATA       ata registro precos   345.0
# 3            EDITAL           EDITAL  edital pregao presencial   341.0
# 4            EDITAL           EDITAL                    edital   277.0
# ..              ...              ...                       ...     ...
# 270          OUTROS           OUTROS     cronograma financeiro     1.0
# 271          OUTROS           OUTROS        custo   secretaria     1.0
# 272          OUTROS           OUTROS      custos totais   item     1.0
# 273          OUTROS           OUTROS        decisao impugnacao     1.0
# 274          OUTROS           OUTROS                   cotacao     1.0
#
#              final_class validate                                 obs  \
# 0                 edital       no                                 NaN
# 1               contrato       no                                 NaN
# 2    ata registro precos       no                                 NaN
# 3                 edital       no                                 NaN
# 4                 edital       no                                 NaN
# ..                   ...      ...                                 ...
# 270               outros       no                                 NaN
# 271               outros       no                       São planilhas
# 272               outros       no                       São planilhas
# 273           impugnacao       no                                 NaN
# 274              cotacao       no  Provavelmente vai se tornar outros
#
#                                                 cities  num_cities  \
# 0    passa-vinte, pirapetinga, coqueiral, sao-bento...         8.0
# 1                               coqueiral, pirapetinga         2.0
# 2    coqueiral, pirapetinga, sao-bento-abade, cristais         4.0
# 3    ribeirao-vermelho, pirapetinga, coqueiral, sao...         5.0
# 4    passa-vinte, ribeirao-vermelho, pirapetinga, c...         6.0
# ..                                                 ...         ...
# 270                                             olaria         1.0
# 271                                           arantina         1.0
# 272                                          coqueiral         1.0
# 273                                          coqueiral         1.0
# 274                                          coqueiral         1.0
#
#                               example
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 270  79a70b2e386a7ae63c8435c2a41f12a6
# 271  d15742de0065437aa2223226aa014703
# 272  7e25efd5d0788cd6b03ff60f357f3438
# 273  a077d756699e6b653b6814d2bcf05b78
# 274  68f64b0b083fe26ed7f3f657c8f549b9
#
# [275 rows x 10 columns]

# %%
df_classes["final_class"].nunique()
# Out:
# 49

# %%
df_classes.groupby('validate').size()
# Out:
# validate
# no     235
# yes     39
# dtype: int64

# %%
df_classes_v1 = df_classes.groupby('processed_classes').agg({'final_class': lambda x: x.iloc[0], 'count':sum, 'cities': lambda x: list(x)}).reset_index()
df_classes_v1['cities'] = df_classes_v1['cities'].apply(lambda x: flatten([y.split(',') for y in x]))
df_classes_v1['num_cities'] = df_classes_v1['cities'].apply(lambda x: len(x))

df_classes_v1.to_csv('resultado_m03_meta_classes_extraction/anexo_a.csv')

# %% [markdown]
# ### Gera Tabela 1

# %%
df_classes_v2 = df_classes.groupby('final_class').agg({'count':sum, 'cities': lambda x: list(x), 'final_meta-class': lambda x: list(x)}).reset_index()
df_classes_v2['cities'] = df_classes_v2['cities'].apply(lambda x: flatten([y.split(',') for y in x]))
df_classes_v2['final_meta-class'] = df_classes_v2['final_meta-class'].apply(lambda x: flatten([y.split(',') for y in x]))
df_classes_v2['num_cities'] = df_classes_v2['cities'].apply(lambda x: len(x))
df_classes_v2.to_csv('resultado_m03_meta_classes_extraction/tabela1.csv')
#df_classes_v2 = df_classes.groupby('processed_classes').agg({'count':sum, 'cities': lambda x: x.str.split(',')}).reset_index()
df_classes_v2
# Out:
#                          final_class   count  \
# 0                             adendo     1.0
# 1                      adendo edital    23.0
# 2                         aditamento   212.0
# 3                        adjudicacao    61.0
# 4                              anexo     4.0
# 5                 anulacao licitacao     2.0
# 6             ata dispensa licitacao   181.0
# 7                     ata julgamento    11.0
# 8              ata pregao presencial   153.0
# 9                ata registro precos   352.0
# 10                ata sessao publica    20.0
# 11                             aviso   314.0
# 12                          contrato   528.0
# 13                           cotacao     4.0
# 14      cronograma fisico financeiro    15.0
# 15                           decisao    21.0
# 16                        declaracao     3.0
# 17                          despacho     4.0
# 18                  diario municipal     9.0
# 19                          distrato     4.0
# 20                            edital  2217.0
# 21                            errata    37.0
# 22                           extrato   126.0
# 23                  gasto homologado   126.0
# 24                       homologacao    75.0
# 25           homologacao adjudicacao    14.0
# 26  homologacao adjudicacao extratos   229.0
# 27                        impugnacao    24.0
# 28                        julgamento     1.0
# 29                      manifestacao     1.0
# 30                   memoria calculo    12.0
# 31               memorial descritivo    20.0
# 32                      nota empenho    12.0
# 33                     ordem servico    15.0
# 34                       outras atas    55.0
# 35                            outros   116.0
# 36                  outros contratos    20.0
# 37                     outros termos    39.0
# 38                           parecer     6.0
# 39                          planilha    26.0
# 40                 processo seletivo     5.0
# 41         publicacao diario oficial   174.0
# 42                       ratificacao   153.0
# 43                         relatorio     8.0
# 44                       retificacao    46.0
# 45                         revogacao     1.0
# 46                     termo aditivo   112.0
# 47                    termo contrato    52.0
# 48                          tutorial    52.0
#
#                                                cities final_meta-class  \
# 0                                   [sao-bento-abade]         [OUTROS]
# 1                         [cristais, sao-bento-abade]         [OUTROS]
# 2                                         [coqueiral]         [OUTROS]
# 3                          [pirapetinga, passa-vinte]        [HOMOLOG]
# 4              [cristais, coqueiral, sao-bento-abade]         [OUTROS]
# 5                                       [pirapetinga]         [OUTROS]
# 6                                          [cristais]            [ATA]
# 7            [pirapetinga, sao-bento-abade, cristais]            [ATA]
# 8                         [cristais, sao-bento-abade]            [ATA]
# 9   [pirapetinga, coqueiral, sao-bento-abade, cris...            [ATA]
# 10                     [passa-vinte, sao-bento-abade]            [ATA]
# 11  [pirapetinga, coqueiral, itamarati, cristais, ...         [OUTROS]
# 12  [pirapetinga, coqueiral, itamarati, sao-bento-...         [OUTROS]
# 13                                        [coqueiral]         [OUTROS]
# 14                           [pirapetinga, coqueiral]         [OUTROS]
# 15  [coqueiral, cristais, ribeirao-vermelho, arant...         [OUTROS]
# 16                                        [coqueiral]         [OUTROS]
# 17                                         [cristais]         [OUTROS]
# 18                                      [passa-vinte]         [OUTROS]
# 19                                        [coqueiral]         [OUTROS]
# 20  [pirapetinga, coqueiral, itamarati, cristais, ...         [EDITAL]
# 21  [coqueiral, itamarati, cristais, ribeirao-verm...         [OUTROS]
# 22  [pirapetinga, coqueiral, itamarati, cristais, ...         [OUTROS]
# 23                                         [cristais]         [OUTROS]
# 24    [pirapetinga, ijaci, cristais, sao-bento-abade]        [HOMOLOG]
# 25          [pirapetinga, itamarati, sao-bento-abade]        [HOMOLOG]
# 26          [passa-vinte, itamarati, sao-bento-abade]        [HOMOLOG]
# 27    [coqueiral, sao-bento-abade, ribeirao-vermelho]         [OUTROS]
# 28                                        [coqueiral]         [OUTROS]
# 29                                      [pirapetinga]         [OUTROS]
# 30                           [pirapetinga, coqueiral]         [OUTROS]
# 31                           [pirapetinga, coqueiral]         [OUTROS]
# 32                                      [pirapetinga]         [OUTROS]
# 33                                        [coqueiral]         [OUTROS]
# 34  [pirapetinga, coqueiral, itamarati, cristais, ...            [ATA]
# 35  [pirapetinga, coqueiral, cristais, sao-bento-a...         [OUTROS]
# 36                                        [coqueiral]         [OUTROS]
# 37  [pirapetinga, coqueiral, cristais, sao-bento-a...         [OUTROS]
# 38  [pirapetinga, ijaci, cristais, ribeirao-vermelho]         [OUTROS]
# 39  [pirapetinga, coqueiral, cristais, ribeirao-ve...         [OUTROS]
# 40                              [coqueiral, cristais]         [OUTROS]
# 41                            [cristais, passa-vinte]         [OUTROS]
# 42  [pirapetinga, coqueiral, itamarati, sao-bento-...         [OUTROS]
# 43                            [pirapetinga, arantina]         [OUTROS]
# 44           [olaria, coqueiral, itamarati, cristais]         [OUTROS]
# 45                                      [pirapetinga]         [OUTROS]
# 46                         [pirapetinga, passa-vinte]         [OUTROS]
# 47                           [pirapetinga, coqueiral]         [OUTROS]
# 48  [arantina, coqueiral, sao-bento-abade, passa-v...         [OUTROS]
#
#     num_cities
# 0            1
# 1            2
# 2            1
# 3            2
# 4            3
# 5            1
# 6            1
# 7            3
# 8            2
# 9            4
# 10           2
# 11           8
# 12           4
# 13           1
# 14           2
# 15           6
# 16           1
# 17           1
# 18           1
# 19           1
# 20          10
# 21           6
# 22           5
# 23           1
# 24           4
# 25           3
# 26           3
# 27           3
# 28           1
# 29           1
# 30           2
# 31           2
# 32           1
# 33           1
# 34           5
# 35           9
# 36           1
# 37           5
# 38           4
# 39           5
# 40           2
# 41           2
# 42           6
# 43           2
# 44           4
# 45           1
# 46           2
# 47           2
# 48           4

# %% [markdown]
# # Gera tabela com classe final por documento

# %%
df_classe_final = pd.read_excel(file_dir, sheet_name="tabelaAgrupamento")
# Seleciona apenas colunas de classes
df_classe_final = df_classe_final[['final_class', 'Proposta de agrupamento']]
# Renomeia colunas
df_classe_final.columns = ['final_class', 'label']
# Recupera processed classes
df_classe_final = pd.merge(left = df_classe_final, right=df_classes[['real_meta-class','final_meta-class','processed_classes', 'final_class']], on='final_class')
# Recupera doc_id
df_classe_final = pd.merge(left = df_classe_final, right=df_rotulos[['doc_id', 'real_meta-class', 'processed_classes']], on = ['real_meta-class', 'processed_classes'])
# Filtra colunas relevantes
df_classe_final = df_classe_final[['doc_id', 'final_meta-class', 'label']]
df_classe_final.to_csv("resultado_m03_meta_classes_extraction/relacao_documentos_label.csv", index=False)

# %% [markdown]
# # Gera tabela com classe final agrupadas por documento

# %%
df_classe_final = pd.read_excel(file_dir, sheet_name="tabelaAgrupamento")
# Seleciona apenas colunas de classes
df_classe_final = df_classe_final[['final_class', 'Proposta de agrupamento']]
# Renomeia colunas
df_classe_final.columns = ['final_class', 'label']
# Recupera processed classes
df_classe_final = pd.merge(left = df_classe_final, right=df_classes[['real_meta-class','final_meta-class','processed_classes', 'final_class']], on='final_class')
# Recupera doc_id
df_classe_final = pd.merge(left = df_classe_final, right=df_rotulos[['doc_id', 'real_meta-class', 'processed_classes']], on = ['real_meta-class', 'processed_classes'])

# Agrupa classes de ata
atas_agrupar = ['ata julgamento', 'ata sessao publica']
df_classe_final.loc[df_classe_final['label'].isin(atas_agrupar), 'label'] = 'outras atas'

# Agrupa classes de homologacao e adjudicacao
adj_homo_agrupar = ['adjudicacao', 'homologacao']
df_classe_final.loc[df_classe_final['label'].isin(adj_homo_agrupar), 'label'] = 'homologacao adjudicacao'

# Agrupa outras classes 
outros_agrupar = ['outros termos', 'decisao/impugnacao', 'planilhas', 'memorial', 'extrato']
df_classe_final.loc[df_classe_final['label'].isin(outros_agrupar), 'label'] = 'outros'
# Filtra colunas relevantes
df_classe_final = df_classe_final[['doc_id', 'final_meta-class', 'label']]
df_classe_final = pd.merge(df_classe_final, df_rotulos[['doc_id', 'meta-class']], on="doc_id")
df_classe_final.to_csv("resultado_m03_meta_classes_extraction/relacao_documentos_label_v2_sandbox.csv", index=False)

# %%
df_classe_final.groupby('label').size()
